# %% [markdown]
# ## penambangan data
# Data Mining atau penambangan data adalah serangkaian proses komputasi untuk menemukan pola, korelasi, dan anomali dalam kumpulan data yang besar. Melalui teknik statistik dan algoritma pembelajaran mesin (Machine Learning), proses ini bertujuan untuk mengubah data mentah menjadi informasi berharga yang dapat mendukung pengambilan keputusan strategis.
#
# Struktur Proses Penambangan Data (CRISP-DM).
# Berikut adalah penjelasan mendalam mengenai lima tahap utama dalam siklus hidup proyek penambangan data berdasarkan struktur yang Anda berikan:
#
# ### 1. Business Understanding (Pemahaman Bisnis)
# Tahap awal ini berfokus pada pemahaman tujuan dan kebutuhan proyek dari sudut pandang organisasi atau pengguna.
#
# - Menentukan Tujuan Bisnis: Langkah ini melibatkan identifikasi masalah utama yang ingin diselesaikan melalui analisis data agar hasil proyek memiliki dampak yang nyata.
#
# - Menilai Situasi: Proses ini mencakup evaluasi ketersediaan sumber daya, perangkat lunak yang diperlukan, serta potensi hambatan yang mungkin muncul selama proyek berjalan.
#
# - Menentukan Tujuan Data Mining: Tujuan bisnis yang bersifat umum diterjemahkan ke dalam parameter teknis data, seperti menetapkan jenis algoritma klasifikasi yang akan digunakan.
#
# ### 2. Data Understanding (Pemahaman Data)
# Fokus pada tahap ini adalah pengenalan mendalam terhadap karakteristik dan kualitas data mentah yang telah dikumpulkan.
#
# - Mengumpulkan Data: Data diekstraksi dari berbagai sumber, seperti file CSV atau basis data, untuk dijadikan bahan baku utama dalam analisis selanjutnya.
#
# - Mendeskripsikan Data: Peneliti memeriksa jumlah instansi (baris), fitur (kolom), serta tipe data untuk memastikan formatnya sesuai dengan kebutuhan sistem.
#
# - Eksplorasi Data: Dilakukan pengecekan awal melalui teknik visualisasi untuk menemukan tren sederhana atau hubungan antar variabel dalam dataset.
#
# #### I. Mengumpulkan Data
# Proses pengambilan dan pemuatan dataset ke dalam lingkungan analisis.
#
# Dataset yang digunakan adalah file IRIS.csv yang terdiri dari 150 observasi. Data ini mencakup pengukuran morfologi dari tiga spesies bunga Iris berbeda yaitu Iris-setosa, Iris-versicolor, dan Iris-virginica. Setiap sampel memiliki 4 fitur numerik (panjang dan lebar kelopak/mahkota) dan 1 label kategori.
#
# #### II. Mendeskripsikan Data
# Identifikasi struktur, tipe data, dan definisi setiap variabel dalam dataset.
#
# Dataset ini memiliki 5 kolom utama. Fitur sepal_length, sepal_width, petal_length, dan petal_width bertipe float (angka desimal dalam cm). Sedangkan kolom species bertipe string yang berisi nama kelas target: Iris-setosa, Iris-versicolor, dan Iris-virginica.
#
# berikut merupakan deskripsi dari sepal dan petal:
# - Sepal (Kelopak Bunga) adalah bagian terluar bunga yang melindungi kuncup sebelum mekar. Pada dataset Iris, sepal diukur panjangnya (4,3–7,9 cm) dan lebarnya (2,0–4,4 cm). Meski umumnya berwarna hijau, pada bunga Iris sepal sering berwarna sama dengan mahkota.
# - Petal (Mahkota Bunga) adalah bagian dalam bunga yang berwarna-warni dan berfungsi menarik penyerbuk. Pada dataset Iris, petal diukur panjangnya (1,0–6,9 cm) dan lebarnya (0,1–2,5 cm). Perbedaan ukuran petal antar spesies sangat signifikan, menjadikannya fitur utama dalam klasifikasi.
#
# berikut merupakan pengertian dari 3 spesies iris:
# - Iris Setosa memiliki ukuran paling kecil, terutama pada mahkota bunganya (petal) yang sangat pendek dan sempit (panjang 1,0–1,9 cm, lebar 0,1–0,6 cm). Ciri khas ini membuatnya mudah dipisahkan dari dua spesies lainnya.
# - Iris Versicolor berukuran sedang, dengan panjang mahkota 3,0–5,1 cm dan lebar 1,0–1,8 cm. Posisinya berada di antara Setosa dan Virginica.
# - Iris Virginica berukuran paling besar, dengan mahkota terpanjang (4,5–6,9 cm) dan terlebar (1,4–2,5 cm).
#
# #### III. Eksplorasi Data
# Peninjauan pola awal, distribusi, dan hubungan antar variabel.
#
# Hasil observasi menunjukkan distribusi kelas yang seimbang (50 sampel per spesies). Secara visual, spesies Iris-setosa memiliki ukuran petal yang jauh lebih kecil dan terpisah secara linier dari spesies lain, menjadikannya fitur pembeda yang sangat kuat dalam analisis klasifikasi.
#
# #### IV. Verifikasi Kualitas Data
# Pemeriksaan kebersihan data untuk memastikan kelayakan analisis.
#
# Verifikasi menunjukkan bahwa dataset ini memiliki kualitas yang sangat baik. Tidak ditemukan nilai yang hilang (missing values) atau data kosong (null). Penamaan label kategori juga sudah konsisten, sehingga data siap digunakan untuk pemodelan tanpa proses pembersihan (data cleaning) tambahan yang rumit.
#
# #### V. Eksplorasi iris menggunakan orange
# **A**
# ![image.png](data:image/png;base64,...)
# - File: Mengimpor dataset Iris (150 data, 4 atribut numerik, 1 kelas).
# - Select Columns: Menentukan fitur utama (sepal & petal) dan target klasifikasi (species).
# - Data Table: Melihat isi, struktur, dan detail data mentah secara tabular.
# - Feature Statistics: Menampilkan statistik deskriptif dasar seperti mean, min, max, dan sebaran data.
# - Rank: Melakukan pemeringkatan fitur untuk mengetahui atribut yang paling berpengaruh terhadap target (umumnya fitur petal).
# - Scatter Plot: Visualisasi korelasi antar variabel untuk melihat pemisahan kelas secara spasial.
# - Box Plot: Membandingkan distribusi dan variansi setiap fitur berdasarkan spesies.
# -Correlations: Menganalisis kekuatan hubungan statistik antar atribut numerik.
# - Pivot Table: Melakukan agregasi untuk mengecek distribusi jumlah data tiap kelas (masing-masing 50 sampel).
#
# **B**
# ![image.png](data:image/png;base64,...)
# mengimpor dataset IRIS.csv yang berisi 150 sampel data bunga Iris dengan empat fitur numerik utama
#
# **C**
# ![image.png](data:image/png;base64,...)
# dataset ini memiliki 150 baris dan 5 kolom tanpa ada nilai kosong (missing value). Setiap baris berisi data ukuran bunga serta label species (Setosa, Versicolor, Virginica). Karena strukturnya bersih, data ini siap digunakan untuk analisis klasifikasi tanpa perlu pembersihan ulang.
#
# **D**
# ![image.png](data:image/png;base64,...)
# Column Statistics merangkum nilai numerik dari 150 sampel data:
# - sepal_length: Memiliki rata-rata (Mean) 5.843, nilai tengah (Median) 5.8, dan nilai tersering (Mode) 5.0.
# - sepal_width: Memiliki rata-rata 3.054, nilai tengah 3.0, dan nilai tersering 3.0.
# - petal_length: Memiliki rata-rata 3.759, nilai tengah 4.350, dan nilai tersering 1.5.
# - petal_width: Memiliki rata-rata 1.199, nilai tengah 1.3, dan nilai tersering 0.2.
#
# Secara keseluruhan, setiap atribut memiliki sebaran data yang lengkap tanpa adanya nilai kosong (Missing: 0). Melalui visualisasi warna, terlihat jelas perbedaan distribusi nilai antara Iris-setosa (biru), Iris-versicolor (merah), dan Iris-virginica (hijau) pada masing-masing fitur.
#
# **E**
# ![image.png](data:image/png;base64,...)
# Widget ini menentukan fitur yang paling berpengaruh dalam membedakan spesies menggunakan metode Gain Ratio dan Gini:
# - Petal sebagai Indikator Utama: Fitur petal_length (0.544) dan petal_width (0.532) memiliki skor tertinggi, yang berarti ukuran kelopak adalah faktor pembeda spesies yang paling kuat.
# - Sepal sebagai Indikator Pendukung: Fitur sepal_length dan sepal_width memiliki skor lebih rendah, menunjukkan pengaruh yang lebih kecil dalam proses klasifikasi dibandingkan fitur petal.
#
# **F**
# ![image.png](data:image/png;base64,...)
# Visualisasi hubungan antara petal_length dan petal_width menunjukkan pemisahan kelas yang jelas:
# - Iris-setosa (biru) membentuk kelompok terpisah yang sangat kontras di area nilai rendah.
# - Iris-versicolor (merah) dan Iris-virginica (hijau) memiliki tren linear yang serupa namun tetap membentuk klaster yang dapat dibedakan pada nilai yang lebih tinggi.
#
#
# **G**
#
# ![image.png](data:image/png;base64,...)
# Menampilkan distribusi nilai per variabel, seperti petal_length yang memiliki rata-rata keseluruhan 3.759 dengan rentang nilai yang bervariasi antar spesies.
#
#
# **H**
#
# ![image.png](data:image/png;base64,...)
# 1. Hubungan Positif Sangat Kuat (Dominasi Fitur Petal)
# - Petal Length & Petal Width (+0.963): Memiliki korelasi tertinggi. Ini menunjukkan bahwa pertumbuhan panjang dan lebar mahkota bunga terjadi secara sangat konsisten dan proporsional.
# - Petal Length & Sepal Length (+0.872): Korelasi kuat yang menunjukkan bahwa bunga dengan mahkota panjang cenderung memiliki kelopak luar yang panjang pula.
# 2. Hubungan Negatif dan Lemah (Anomali Sepal Width)
# - Sepal Width menunjukkan perilaku yang berbeda dari variabel lain, dengan korelasi negatif terhadap petal_length (-0.421) dan petal_width (-0.357).
# - Sepal Length & Sepal Width (-0.109): Memiliki korelasi terendah (mendekati nol), yang berarti hampir tidak ada hubungan linear antara panjang dan lebar kelopak luar.
# 3. Implikasi untuk Analisis Lanjutan
# - Fitur Paling Informatif: Fitur Petal (panjang dan lebar) adalah fitur paling krusial dan saling berkaitan erat, sehingga sangat efektif digunakan untuk klasifikasi spesies.
# - Redundansi Data: Karena korelasi petal_length dan petal_width sangat mendekati +1, salah satu fitur ini sudah cukup mewakili informasi mahkota bunga dalam model statistik tertentu.
#
# **I**
#
# ![image.png](data:image/png;base64,...)
# - Dataset Seimbang (Balanced Dataset): Setiap kelas memiliki proporsi tepat 33,3%, sehingga meminimalkan risiko bias pada algoritma klasifikasi.
# - Integritas Data: Diagonal matriks yang konsisten pada angka 50 menunjukkan validitas data tanpa adanya nilai yang hilang (missing values) pada kolom spesies.
#
# #### VI. Eksplorasi iris menggunakan collab (Python)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc0c01ae-d525-4788-aeda-a64b5e9d6766" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc0c01ae-d525-4788-aeda-a64b5e9d6766">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("IRIS.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(
    x="petal_length",
    y="petal_width",
    hue="species",
    data=df
)

plt.title("Scatter Plot Petal Length vs Petal Width")
plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
import pandas as pd
df = pd.read_csv("IRIS.csv")
print(f"Ada {df.duplicated().sum()} data duplikat dari total {len(df)} baris")
# Out:
# Ada 3 data duplikat dari total 150 baris

# %%
import pandas as pd

df = pd.read_csv("IRIS.csv")

duplicate_values = df[df.duplicated()][['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']]
print("Nilai-nilai yang duplikat:")
print(duplicate_values)
# Out:
# Nilai-nilai yang duplikat:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %% [markdown]
# Berdasarkan pengecekan yang telah dilakukan pada file IRIS.csv, ditemukan bahwa terdapat 3 data duplikat dari total 150 baris dataset. Data duplikat tersebut terdiri dari dua kelompok: satu pasang pada spesies Iris-setosa dengan nilai [4.9, 3.1, 1.5, 0.1] dan satu pasang pada spesies Iris-virginica dengan nilai [5.8, 2.7, 5.1, 1.9].
#
# #### Mengukur Jarak dengan Tipe Data Campuran
# Data campuran adalah data yang memiliki lebih dari satu tipe atribut, misalnya:
# - Numerik → sepal length, sepal width
# - Kategorikal → jenis kelamin, spesies bunga
# - Ordinal → ranking, tingkat kepuasan
#
# ✓ Jika semua data numerik → bisa pakai Euclidean Distance biasa.
#
# ✓ Tapi kalau campuran → tidak bisa langsung dihitung begitu saja.
#
# untuk mengukur jarak dengan tipe data campuran kita bisa menggunakan metode Gower Distance yang diperkenalkan oleh J. C. Gower pada tahun 1971. karena metode ini menghitung setiap atribut sesuai sifatnya dan menghasilkan nilai jarak dalam rentang 0–1 yang mudah diinterpretasikan.
#
#
#
# ##### **Rumus Gower Distance**
# $$
# D_{ij} = \frac{1}{p} \sum_{k=1}^{p} s_{ijk}
#  $$
#
# Dimana:
#
# - $D_{ij}$ = jarak antara objek $i$ dan $j$
# - $p$ = jumlah atribut
# - $s_{ijk}$ = skor ketidakmiripan pada atribut ke-$k$
#
# Nilai akhirnya berada di rentang:
#
# $$
# 0 \leq D_{ij} \leq 1
# $$
#
# - 0 → sangat mirip
# - 1 → sangat berbeda
#
# **contoh**
#
# | Nama  |Berat Badan (kg) | Hobi     |Memiliki Laptop |
# | ----- | --------------  | -------- | -------------- |
# | Tia   |      55         | Menonton | Ya             |
# | Harum |      70         | Membaca  | Ya             |
#
#
# *Jenis data:*
# - Berat Badan: numerik
# - Hobi: kategorikal
# - Memiliki Laptop: biner
#
#
# Range = 80 - 50 = 30
#
# $$
# d_1 = \frac{|55 - 70|}{30}
#      = \frac{15}{30}
#      = 0.5
# $$
#
# *Kategori*
# - Hobi Berbeda → $d_2 = 1$
# - Memiliki Laptop Sama  → $d_3 = 0$
#
# *Hasil*
#
# $$
# D_{AB} = \frac{0.5 + 1 + 0}{3}
# $$
#
# $$
# D_{AB} = 0.5
# $$
#
# **Kelebihan Gower Distance**
#
# ✅ Bisa untuk data campuran
#
# ✅ Sudah dinormalisasi otomatis
#
# ✅ Cocok untuk clustering
#
# ✅ Cocok untuk KNN data campuran
#
# **Kekurangan Gower Distance**
# - Sensitif terhadap range numerik
# - Jika banyak kategorikal → jarak bisa besar
# - Perlu preprocessing untuk ordinal
#
# #### VII. analisis dan implementasi menggunakan orange untuk data campuran(IRIS).
# ![image.png](data:image/png;base64,...)
# Workflow ini dimulai dari File yang membaca dataset IRIS.csv, lalu Select Columns memisahkan 4 fitur numerik dan target species. Selanjutnya Distances menghitung jarak antar sampel menggunakan Euclidean yang dinormalisasi, lalu hasilnya divisualisasikan melalui MDS, Hierarchical Clustering, dan Distance Map. Sementara itu, Box Plot menampilkan distribusi fitur untuk melihat karakteristik masing-masing species.
#
# **A. File**
# ![image.png](data:image/png;base64,...)
# Widget File menampilkan dataset IRIS.csv yang sudah di-load. Dataset ini punya 150 baris data dengan 5 kolom, terdiri dari 4 kolom numerik (sepal_length, sepal_width, petal_length, petal_width) sebagai fitur dan 1 kolom kategorikal (species) sebagai target dengan nilai Iris-setosa, Iris-versicolor, dan Iris-virginica. Semua data lengkap tidak ada yang kosong.
#
#
# **B. Select Columns**
# ![image.png](data:image/png;base64,...)
#
# Widget Select Columns memisahkan kolom berdasarkan perannya.
# 4 kolom numerik (sepal_length, sepal_width, petal_length, petal_width) masuk Features untuk dihitung jaraknya.
# 1 kolom kategorikal (species) masuk Target sebagai label visualisasi.
# Pemisahan seperti ini membuat Orange paham mana data yang dipakai buat hitung jarak dan mana yang cuma buat pewarnaan.
#
#
# **C. Distances**
#
# ![image.png](data:image/png;base64,...)
#
# Widget Distances adalah tempat untuk menghitung jarak antar data.
# - Centangan Rows artinya kita menghitung jarak antar baris (antar sampel bunga), bukan antar kolom.
# - Pilihan Euclidean (normalized) dipakai karena data numerik dan skala tiap kolom berbeda, jadi perlu dinormalisasi dulu biar adil.
# - Hasilnya berupa matriks ukuran 150 × 150 yang berarti jarak antara 150 sampel satu sama lain sudah dihitung semua.
#
# **D. MDS**
#
# ![image.png](data:image/png;base64,...)
#
# Widget MDS menampilkan hasil perhitungan jarak dalam bentuk plot 2D.
# - Nilai Kruskal Stress 0.051 menunjukkan plot ini bagus karena di bawah 0,15 artinya posisi titik di gambar mirip dengan jarak aslinya.
# - Warna titik dibedakan berdasarkan species biar keliatan jelas kelompok Setosa, Versicolor, dan Virginica.
# - Show legend dicentang jadi ada keterangan warna di samping plot.
#
# Dari plot ini terlihat Setosa mengelompok sendiri sementara Versicolor dan Virginica berdekatan tapi masih terpisah.
#
# **E. Box Plot
#
# ![image.png](data:image/png;base64,...)
#
# Widget Box Plot menampilkan distribusi data dalam bentuk kotak dan garis.
# - Di bagian Variable bisa dipilih kolom mana yang mau dilihat, misalnya petal_length.
# - Subgroups diisi species biar tampilannya terpisah per kelompok Setosa, Versicolor, dan Virginica.
# - Dari plot ini keliatan petal_length antar species berbeda: Setosa pendek, Versicolor sedang, Virginica panjang, dan ada sedikit overlap antara Versicolor sama Virginica.
#
#
# **F. Hierarchical Clustering**
# ![image.png](data:image/png;base64,...)
#
# Widget Hierarchical Clustering menampilkan dendrogram atau pohon kemiripan antar sampel.
#
# - Linkage pakai Ward yang mengelompokkan berdasarkan keragaman data.
# - Annotations diisi species biar tiap cabang dikasih label.
# - Color by juga species biar warna cabang sesuai kelompok.
#
# Dari hasilnya keliatan ada tiga cabang utama. Satu cabang besar berisi semua Setosa, satu cabang lagi bercabang dua jadi Versicolor dan Virginica. Ini nunjukkin Setosa memang beda sendiri, sementara Versicolor dan Virginica masih mirip.
#
# **G. Distance Map**
#
# ![image.png](data:image/png;base64,...)
#
# Widget Distance Map menampilkan matriks jarak dalam bentuk heatmap.
# - Pengaturan Clustering mengurutkan data berdasarkan kemiripan, dengan warna biru untuk jarak kecil dan kuning untuk jarak besar.
# - Hasilnya menunjukkan tiga blok biru di diagonal yang berarti jarak dalam satu species dekat.
# - Area luar diagonal berwarna terang karena jarak antar species jauh, menegaskan perbedaan antar kelompok.
#
# Dataset Iris diaplikasikan ke Orange dengan menghitung jarak menggunakan Euclidean (normalized) di widget Distances. Hasilnya matriks jarak 150×150. Visualisasi lewat MDS, Hierarchical Clustering, dan Distance Map semuanya menunjukkan tiga kelompok sesuai species.
#
#
#
# ### 3. Data Preparation (Persiapan Data)
# Tahap ini merupakan fase krusial untuk memastikan data dalam kondisi optimal sebelum diproses oleh algoritma cerdas.
#
# - Pembersihan Data (Data Cleaning): Langkah ini dilakukan untuk memperbaiki kesalahan input, menangani nilai yang kosong, atau menghapus data yang tidak relevan.
#
# - Konstruksi Data: Peneliti dapat membuat atribut baru atau mengubah format data yang ada agar pola-pola tersembunyi lebih mudah dikenali oleh model.
#
# - Pengaturan Peran (Role Setting): Menetapkan peran spesifik bagi setiap kolom, seperti menentukan fitur sebagai input dan variabel target sebagai output yang ingin diprediksi.
#
# ### 4. Modelling (Pemodelan)
# Pada tahap ini, berbagai teknik dan algoritma diterapkan untuk menghasilkan model prediksi yang akurat.
#
# - Memilih Teknik Pemodelan: Peneliti memilih algoritma yang paling relevan dengan kasus yang dihadapi, seperti Decision Tree, Random Forest, atau k-Nearest Neighbors.
#
# - Membangun Model: Algoritma dijalankan pada kumpulan data latihan sehingga sistem dapat mempelajari pola hubungan antar variabel secara mandiri.
#
# - Menilai Model: Performa model diuji untuk mengetahui tingkat akurasinya dalam memprediksi data sebelum akhirnya diputuskan untuk digunakan secara luas.
#
# ### 5. Deployment (Implementasi)
# Tahap akhir ini memastikan bahwa pengetahuan atau model yang dihasilkan dapat diakses dan bermanfaat bagi pengguna akhir.
#
# - Merencanakan Deployment: Menyusun strategi mengenai bagaimana model akan diintegrasikan ke dalam sistem operasional atau aplikasi nyata milik organisasi.
#
# - Membuat Laporan Akhir: Seluruh proses dan temuan didokumentasikan secara sistematis sebagai referensi teknis maupun bahan presentasi bagi para pemangku kepentingan.
#
# - Pemeliharaan (Maintenance): Model terus dipantau dan diperbarui secara berkala agar tetap relevan dan akurat meskipun terjadi perubahan tren data di masa mendatang

# %% [markdown]
# ## W-KNN
# Missing Values Imputation menggunakan Weighted K-Nearest Neighbor (WKNN)
#
# *Hasil Excel*
#
#
# ![Screenshot 2026-03-15 221639.png](data:image/png;base64,...)
#
#
# ### 1. Dataset
# |   ID  |  Harga Diskon   |  Tiket Terjual  |
# | ----- | --------------  | --------------- |
# |   1   |      10         |       500       |
# |   2   |      20         |       420       |
# |   3   |      40         |       300       |
# |   4   |      60         |       210       |
# |   5   |      80         |       100       |
# |   6   |      46         |         ?       |
#
# *Data Target*
# - Harga Diskon: 45
# - Tiket terjual: ?
#
# ### 2. Hitung Jarak
# Menggunakan jarak Euclidean untuk mengukur kedekatan antara harga diskon pada dataset dengan harga target (45).
#
# $
# d(x_i, x_j) = (x_i - x_j)^2
# $
#
# Keterangan:
# -  $d$  → Nilai jarak kuadrat hasil perhitungan.
# -  $x_i$  → Harga diskon yang ada di data.
# -  $x_j$  → Harga target yang ingin dicari (45).
# -  $(...)^2$  → Pangkat dua untuk memastikan hasil selalu positif.
#
# |   Tetangga(Harga)  |  Selisih   |  Kuadrat  |
# | ------------------ | ---------- | --------- |
# |         10         |    -35     |    1225   |
# |         20         |    -25     |     625   |
# |         40         |     -5     |     25    |
# |         60         |     15     |     225   |
# |         80         |     35     |    1225   |
#
# ### 3. Hitung Kemiripan
# Menggunakan rumus bobot untuk menentukan seberapa besar pengaruh setiap data tetangga terhadap estimasi data yang hilang.
#
# $$
# w = \frac{1}{d}
# $$
#
# Keterangan:
# -  $w$  → Weight/Bobot
# -  $d$  → Distance/Jarak
# - 1 → konstanta
#
# |   Harga Diskon  |  Tiket Terjual |   Bobot   |
# | --------------- | -------------- | --------- |
# |        10       |      500       | 0.000816  |
# |        20       |      420       | 0.0016    |
# |        40       |      300       | 0.04      |
# |        60       |      210       | 0.004444  |
# |        80       |      100       | 0.000816  |
#
# ### 4. Weighted Average
#
# *Pembilang (Total Bobot x Tiket Terjual):*
#
# (0.000816 × 500) + (0.0016 × 420) + (0.04 × 300) + (0.004444 × 210) + (0.000816 × 100)
# - Hasil: 14.09513
#
# *Penyebut (Total Bobot):*
#
# 0.000816 + 0.0016 + 0.04 + 0.004444 + 0.000816
# - Hasil: 0.047677
#
#
# ### 5. Hasil Estimasi
#
# $$\text{Nilai} = \frac{14,09513}{0,047677}$$
#
# $$\approx 295,641151$$

# %%
harga = [10, 20, 40, 60, 80]
tiket = [500, 420, 300, 210, 100]

target = 45

print("DATASET")
print("Harga Diskon :", harga)
print("Tiket Terjual :", tiket)
print("Target Harga  :", target)
print()
# Out:
# DATASET
# Harga Diskon : [10, 20, 40, 60, 80]
# Tiket Terjual : [500, 420, 300, 210, 100]
# Target Harga  : 45

# %% [markdown]
# ### A. Hitung Selisih
# Data harga yang digunakan: [10, 20, 40, 60, 80] dengan target 45.
# *Proses Pengurangan:*
# - 10 - 45 = -35
# - 20 - 45 = -25
# - 40 - 45 = -5
# - 60 - 45 = 15
# - 80 - 45 = 35
#
# Bagian ini bertujuan untuk mengukur rentang atau jarak linear antara setiap harga di dataset dengan harga target (45). Selisih ini memberi tahu kita posisi data; jika hasilnya negatif berarti di bawah target, dan jika positif berarti di atas target.

# %%
# List harga dan target
harga = [10, 20, 40, 60, 80]
target = 45

# Menghitung selisih satu per satu
selisih = []
for h in harga:
    hasil = h - target
    selisih.append(hasil)

print("Hasil Selisih (Harga - Target):")
print(selisih)
# Out:
# Hasil Selisih (Harga - Target):
# [-35, -25, -5, 15, 35]

# %% [markdown]
# ### B. Hitung kuadrat jarak
# selisih = [-35, -25, -5, 15, 35]
#
#
# $$\begin{aligned} (-35)^2 &= 1225 \\ (-25)^2 &= 625 \\ (-5)^2 &= 25 \\ 15^2 &= 225 \\ 35^2 &= 1225 \end{aligned}$$
#
#
# Setelah selisih didapat, angka-angka tersebut dipangkatkan dua untuk menghilangkan tanda negatif agar semua jarak menjadi bernilai positif (absolut).

# %%
# Menghitung kuadrat untuk setiap elemen dalam list selisih
hasil_kuadrat = [n**2 for n in selisih]

print("Daftar Jarak Kuadrat:")
print(hasil_kuadrat)
# Out:
# Daftar Jarak Kuadrat:
# [1225, 625, 25, 225, 1225]

# %% [markdown]
# ### C. Hitung bobot / kemiripan
#
# Berikut adalah rincian pembagian nilai berdasarkan jarak kuadrat untuk mencari tingkat kemiripan:
#
#
# $$\frac{1}{1225} = 0.000816$$$$\frac{1}{625} = 0.0016$$$$\frac{1}{25} = 0.04$$$$\frac{1}{225} = 0.004444$$$$\frac{1}{1225} = 0.000816$$
#
#
#
# Inti dari tahap ini adalah membalik nilai jarak menjadi bobot. Data yang jaraknya paling kecil (paling dekat dengan harga 45) secara otomatis akan mendapatkan nilai bobot paling besar. Dengan begitu, data yang paling mirip akan memberikan pengaruh paling kuat pada hasil prediksi akhir nanti.

# %%
# 1. Definisikan selisih
selisih = [-35, -25, -5, 15, 35]

# 2. Hitung kuadrat
kuadrat = [s**2 for s in selisih]

# 3. Hitung bobot
hasil_bobot = []
for d in kuadrat:
    if d != 0:
        w = round(1 / d, 6)
        hasil_bobot.append(w)
    else:
        hasil_bobot.append(1.0)

print("Hasil Kuadrat:", kuadrat)
print("Hasil Bobot  :", hasil_bobot)
# Out:
# Hasil Kuadrat: [1225, 625, 25, 225, 1225]
# Hasil Bobot  : [0.000816, 0.0016, 0.04, 0.004444, 0.000816]

# %% [markdown]
# ### D. Hitung bobot × nilai
# Setelah nilai bobot didapat, langkah selanjutnya adalah mengalikan bobot tersebut dengan jumlah tiket terjual dari masing-masing data.
#
# $$0.000816 \times 500 = 0.408163$$$$0.0016 \times 420 = 0.672$$$$0.04 \times 300 = 12$$$$0.004444 \times 210 = 0.933333$$$$0.000816 \times 100 = 0.081633$$
#
# Data yang memiliki bobot besar akan menyumbangkan angka yang lebih signifikan terhadap hasil prediksi. Sebaliknya, data yang jauh hanya akan memberikan kontribusi nilai yang kecil.

# %%
# 1. Data dari tabel
bobot = [0.000816, 0.0016, 0.04, 0.004444, 0.000816]
tiket = [500, 420, 300, 210, 100]

bobot_nilai = []

# 3. Hitung dan tampilkan
for i in range(len(tiket)):
    hasil = bobot[i] * tiket[i]
    bobot_nilai.append(hasil)
    print(f"{bobot[i]} * {tiket[i]} = {hasil}")

print("\nBOBOT x NILAI")
print(bobot_nilai)
# Out:
# 0.000816 * 500 = 0.408
# 0.0016 * 420 = 0.672
# 0.04 * 300 = 12.0
# 0.004444 * 210 = 0.93324
# 0.000816 * 100 = 0.0816
#
# BOBOT x NILAI
# [0.408, 0.672, 12.0, 0.93324, 0.0816]

# %% [markdown]
# ### E. Hitung nilai Pembilang
# Pada tahap ini, merupakan proses menjumlahkan seluruh hasil perkalian antara bobot dan jumlah tiket yang telah dihitung sebelumnya.
#
# $$Pembilang = 0.408163 + 0.672 + 12 + 0.933333 + 0,081633$$$$Pembilang = 14.09513$$
#
# Pembilang merupakan total nilai terbobot yang akan digunakan sebagai angka utama dalam menentukan estimasi akhir.

# %%
# 1. Data
ID = [1, 2, 3, 4, 5]
tiket_terjual = [500, 420, 300, 210, 100]
kuadrat = [1225, 625, 25, 225, 1225]

# List untuk menampung hasil b x Tiket Terjual
bobot_tiket = []

# 2. Proses hitung perkalian
for i in range(len(tiket_terjual)):
    # Bobot adalah 1 dibagi kuadrat
    bobot = 1 / kuadrat[i]
    hasil = bobot * tiket_terjual[i]
    bobot_tiket.append(hasil)

    print(f"ID {ID[i]}: ({bobot:.7f}) * {tiket_terjual[i]} = {hasil:.6f}")

total_pembilang = sum(bobot_tiket)

print("HASIL AKUMULASI PEMBILANG:")
print(f"{total_pembilang:.5f}")
# Out:
# ID 1: (0.0008163) * 500 = 0.408163
# ID 2: (0.0016000) * 420 = 0.672000
# ID 3: (0.0400000) * 300 = 12.000000
# ID 4: (0.0044444) * 210 = 0.933333
# ID 5: (0.0008163) * 100 = 0.081633
# HASIL AKUMULASI PEMBILANG:
# 14.09513

# %% [markdown]
# ### F. Hitung Nilai Penyebut
# Tahap ini dilakukan dengan menjumlahkan seluruh nilai bobot ($w$) yang telah diperoleh untuk digunakan sebagai pembagi pada langkah akhir.
#
#
# $$Penyebut = 0,000816 + 0,0016 + 0,04 + 0,004444 + 0,000816$$$$Penyebut = 0,047677$$
#
#
# Penyebut ini merepresentasikan total kontribusi dari seluruh tetangga terdekat yang digunakan dalam perhitungan. Nilai ini sangat penting untuk menormalisasi hasil prediksi agar angka akhirnya tetap berada dalam skala yang logis (rata-rata terbobot). Dengan membagi pembilang menggunakan total penyebut ini, maka akan mendapatkan estimasi jumlah tiket terjual yang paling mendekati kenyataan berdasarkan kedekatan harga.

# %%
# data
kuadrat = [1225, 625, 25, 225, 1225]

hasil_bobot = []
for k in kuadrat:
    hasil_bobot.append(1 / k)

total_penyebut = sum(hasil_bobot)

print("NILAI TOTAL PENYEBUT:")
print(f"{total_penyebut:.6f}")
# Out:
# NILAI TOTAL PENYEBUT:
# 0.047677

# %% [markdown]
# ### G. Estimasi Nilai
# Hasil akhir didapatkan dengan membagi total pembilang (nilai terbobot) dengan total penyebut (akumulasi bobot):
#
# $$\text{Estimasi} = \frac{\text{Total Pembilang}}{\text{Total Penyebut}}$$$$\text{Estimasi} = \frac{14,09513}{0,047677}$$$$\text{Estimasi} = 295,6373$$
#
# Hasil akhir menunjukkan bahwa pada target harga 45, estimasi tiket yang terjual adalah sebanyak 295,6373 (atau dapat dibulatkan menjadi 296 tiket).

# %%
# 1. Ambil data asli (tanpa pembulatan manual)
kuadrat = [1225, 625, 25, 225, 1225]
tiket = [500, 420, 300, 210, 100]

# 2. Hitung Pembilang dan Penyebut secara otomatis
hasil_bobot = [1/k for k in kuadrat]
hasil_kali = [(1/kuadrat[i]) * tiket[i] for i in range(len(tiket))]

pembilang_akurat = sum(hasil_kali)
penyebut_akurat = sum(hasil_bobot)

# 3. Hitung Estimasi Final
estimasi_final = pembilang_akurat / penyebut_akurat

print(f"Total Pembilang : {pembilang_akurat:.6f}")
print(f"Total Penyebut  : {penyebut_akurat:.6f}")
print(f"ESTIMASI NILAI  : {estimasi_final:.4f}")
# Out:
# Total Pembilang : 14.095129
# Total Penyebut  : 0.047677
# ESTIMASI NILAI  : 295.6373

# %% [markdown]
# ## Normalisasi Data
# Normalisasi data adalah proses transformasi untuk menyamakan skala nilai pada setiap variabel dalam sebuah dataset. Tujuannya adalah agar semua atribut berada dalam rentang yang seragam tanpa menghilangkan pola distribusi data aslinya.
#
# Dalam algoritma yang menggunakan perhitungan jarak, seperti Weighted K-Nearest Neighbor (WKNN), normalisasi sangat wajib dilakukan. Tanpa proses ini, variabel dengan angka yang besar (misalnya: Harga Tiket) akan mendominasi hasil perhitungan dibandingkan variabel dengan angka kecil (misalnya: Harga Diskon). Dengan normalisasi, kita memastikan setiap fitur memberikan kontribusi yang adil dan seimbang dalam menentukan hasil prediksi (menghindari bias).
#
#
#
#
#
# *Hasil ujicoba excel*
#
#
#
# ![image.png](data:image/png;base64,...)
#
# ### Jenis-Jenis Normalisasi Data
# Terdapat beberapa metode normalisasi yang umum digunakan dalam data mining dan machine learning, antara lain Min-Max Normalization, Z-Score Normalization, dan Decimal Scaling.
#
# #### I. Min-Max Normalization
# Min-Max Normalization adalah metode normalisasi yang mengubah nilai data ke dalam rentang tertentu, biasanya antara 0 hingga 1. Metode ini dilakukan dengan mengurangi nilai data dengan nilai minimum kemudian membaginya dengan selisih antara nilai maksimum dan minimum.
#
#
# *Rumus Min-Max Normalization:*
#
#
# $$x' = \frac{x - x_{min}}{x_{max} - x_{min}}$$
#
#
# *Keterangan:*
#
# - $x$ = nilai data asli
# - $x_{min}$ = nilai minimum pada dataset
# - $x_{max}$ = nilai maksimum pada dataset
# - $x'$ = nilai hasil normalisasi
#
#
# *Dataset*
#
# |   Harga Diskon  |  Tiket Terjual |
# | --------------- | -------------- |
# |        10       |      500       |
# |        20       |      420       |
# |        40       |      300       |
# |        60       |      210       |
# |        80       |      100       |
#
#
#
# *Nilai Statistik*
# - Nilai minimum ($x_{min}$) = 10
# - Nilai maksimum ($x_{max}$) = 80
#
# *Contoh Perhitungan*
# - $x' = \frac{10 - 10}{80 - 10} = 0$
# - $x' = \frac{20 - 10}{80 - 10} = 0,142857$
#
# *Hasil Normalisasi*
# |   Harga Diskon  |  Normalisasi |
# | --------------- | ------------ |
# |        10       |      0       |
# |        20       |   0.142857   |
# |        40       |   0.428571   |
# |        60       |   0.714286   |
# |        80       |      1       |

# %%
import numpy as np

# 1. Input Data
harga = [10, 20, 40, 60, 80]
tiket = [500, 420, 300, 210, 100]

# 2. Fungsi hitung Min-Max Normalization
def tampil_minmax(nama, data):
    min_val = min(data)
    max_val = max(data)

    print(f"Min-Max {nama}:")
    for x in data:
        # Rumus: (x - min) / (max - min)
        norm = (x - min_val) / (max_val - min_val)
        print(f"{norm:.9f}")
    print()

# 3. Eksekusi
tampil_minmax("Harga Diskon", harga)
tampil_minmax("Tiket Terjual", tiket)
# Out:
# Min-Max Harga Diskon:
# 0.000000000
# 0.142857143
# 0.428571429
# 0.714285714
# 1.000000000
#
# Min-Max Tiket Terjual:
# 1.000000000
# 0.800000000
# 0.500000000
# 0.275000000
# 0.000000000

# %% [markdown]
# #### II. Z-Score Normalization (Standardization)
#
# Z-Score Normalization mengubah data sehingga memiliki rata-rata (mean) = 0 dan standar deviasi = 1. Metode ini sering digunakan dalam machine learning karena mampu mempertahankan distribusi data.
#
# *Rumus Z-Score:*
#
#
# $$z = \frac{x - \mu}{\sigma}$$
#
# *Keterangan:*
# - $x$ = nilai data
# - $\mu$ = rata-rata data
# - $\sigma$ = standar deviasi
# - $z$ = nilai hasil normalisasi
#
#
# *Contoh*
# - Dataset Harga Diskon: 10, 20, 40, 60, 80
# - Mean ($\mu$)
#
#
# $$10 + 20 + 40 + 60 + 80 = 210$$
#
#
# $$210 / 5 = \mathbf{42}$$
#
# - Standar deviasi ($\sigma$)
#
# Kurangi setiap angka dengan 42, lalu dikuadratkan:
#
# $$10 \rightarrow (10-42)^2 = 1024$$
# $$20 \rightarrow (20-42)^2 = 484$$
# $$40 \rightarrow (40-42)^2 = 4$$
# $$60 \rightarrow (60-42)^2 = 324$$
# $$80 \rightarrow (80-42)^2 = 1444$$
#
# Jumlahkan hasil kuadrat, bagi 5, lalu diakar kuadrat:
#
# $$Total Kuadrat: 1024 + 484 + 4 + 324 + 1444 = \mathbf{3280}$$
# $$Bagi 5: 3280 / 5 = \mathbf{656}$$
# $$Akar Kuadrat: \sqrt{656} = \mathbf{25.61249}$$
#
# - Perhitungan
#
# $$z = \frac{10 - 42}{25.29822} = -1.2649$$
#
# *Tabel Hasil*
# |   Harga Diskon  |    Z-Score   |
# | --------------- | ------------ |
# |        10       |   -1.2649    |
# |        20       |   -0.8696    |
# |        40       |   -0.0790    |
# |        60       |    0.7115    |
# |        80       |    1.5020    |

# %%
import numpy as np

# 1. Input Data
harga = [10, 20, 40, 60, 80]
tiket = [500, 420, 300, 210, 100]

# 2. Fungsi hitung Z-Score
def tampil_zscore(nama, data):
    mu = np.mean(data)
    sigma = np.std(data)

    print(f"Z-Score {nama}:")
    for x in data:
        z = (x - mu) / sigma
        print(f"{z:.9f}")
    print()

# 3. Eksekusi
tampil_zscore("Harga Diskon", harga)
tampil_zscore("Tiket Terjual", tiket)
# Out:
# Z-Score Harga Diskon:
# -1.249390095
# -0.858955690
# -0.078086881
# 0.702781928
# 1.483650738
#
# Z-Score Tiket Terjual:
# 1.356146059
# 0.796910571
# -0.041942662
# -0.671082586
# -1.440031383

# %% [markdown]
# #### III. Decimal Scaling
#
# Decimal Scaling adalah metode normalisasi dengan memindahkan posisi desimal dari nilai data hingga nilai maksimum berada dalam rentang tertentu (biasanya antara -1 dan 1).
#
# *Rumus*
#
#
# $$x' = \frac{x}{10^j}$$
#
# *Keterangan*
#
# - $x$ = nilai data asli
# - $j$ = jumlah digit maksimum pada data
#
# *Data Harga Diskon*
#
# - Data: $10, 20, 40, 60, 80$
# - Nilai maksimum = $80$
# - Jumlah digit ($j$) = $2$
# - Maka pembaginya adalah $10^2 = 100$
#
#
#
# |   Harga Diskon  |  Perhitungan |   Decimal Scaling   |
# | --------------- | ------------ | ------------------- |
# |        10       |    10/100    |         0.1         |
# |        20       |    20/100    |         0.2         |
# |        40       |    40/100    |         0.4         |
# |        60       |    60/100    |         0.6         |
# |        80       |    80/100    |         0.8         |
#
#
#
#
#
# *Data Tiket Terjual*
#
# - Data: $500, 420, 300, 210, 100$
# - Nilai maksimum = $500$
# - Jumlah digit ($j$) = $3$
# - Maka pembaginya adalah $10^3 = 1000$
#
# |   Tiket Terjual  |   Perhitungan  |   Decimal Scaling   |
# | ---------------  | -------------  | ------------------- |
# |        500       |    500/1000    |         0.5         |
# |        420       |    420/1000    |         0.42        |
# |        300       |    300/1000    |         0.3         |
# |        210       |    210/1000    |         0.21        |
# |        100       |    100/1000    |         0.1         |

# %%
import numpy as np

# 1. Input Data
harga = [10, 20, 40, 60, 80]
tiket = [500, 420, 300, 210, 100]

def decimal_scaling(nama, data):
    max_val = max(abs(x) for x in data)
    j = len(str(int(max_val)))
    pembagi = 10**j

    print(f"Decimal Scaling {nama} (j={j}):")
    for x in data:
        print(x / pembagi)
    print()

# 2. Eksekusi
decimal_scaling("Harga Diskon", harga)
decimal_scaling("Tiket Terjual", tiket)
# Out:
# Decimal Scaling Harga Diskon (j=2):
# 0.1
# 0.2
# 0.4
# 0.6
# 0.8
#
# Decimal Scaling Tiket Terjual (j=3):
# 0.5
# 0.42
# 0.3
# 0.21
# 0.1
